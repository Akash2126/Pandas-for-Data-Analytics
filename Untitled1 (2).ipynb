# %%
import pandas as pd 
data = pd.read_excel("netflix_data.xlsx")
#print(data)
print(data.head(50))
print(data.info())
# Out:
#         N_id                                   Title   Main Genre  \
# 0     215309              Ace Ventura: Pet Detective       Comedy
# 1     215318          Ace Ventura: When Nature Calls       Comedy
# 2     217258                       The Addams Family       Comedy
# 3     217303                    Addams Family Values       Comedy
# 4     235527                               Agneepath        Drama
# 5     265929                               Assassins       Action
# 6     268371                              Awakenings        Drama
# 7     318960                            Blue Thunder       Action
# 8     374329              A Chinese Odyssey (Part I)       Action
# 9     538871            Geronimo: An American Legend        Drama
# 10    547335                                   Glory        Drama
# 11    557010                  Grave of the Fireflies        Anime
# 12    609910                             Hudson Hawk       Action
# ...

# %%
data.describe()
# Out:
#                N_id  Release Year
# count  6.403000e+03   6402.000000
# mean   7.971379e+07   2019.077320
# std    7.159805e+06      6.094716
# min    2.153090e+05   1962.000000
# 25%    8.022148e+07   2018.000000
# 50%    8.122164e+07   2021.000000
# 75%    8.151819e+07   2022.000000
# max    8.199405e+07   2025.000000

# %%
print(data.isnull())
# Out:
#        N_id  Title  Main Genre  Sub Genres  Release Year  Maturity Rating  \
# 0     False  False       False       False         False            False
# 1     False  False       False       False         False            False
# 2     False  False       False       False         False            False
# 3     False  False       False       False         False            False
# 4     False  False       False       False         False            False
# ...     ...    ...         ...         ...           ...              ...
# 6398  False  False       False       False         False            False
# 6399  False  False       False       False         False            False
# 6400  False  False       False       False         False            False
# 6401  False  False       False       False         False            False
# 6402  False  False       False       False         False            False
#
#       Original Audio  Recommendations
# 0              False            False
# ...

# %%
print(data.isnull().sum())
# Out:
# N_id                  0
# Title                 0
# Main Genre            0
# Sub Genres            0
# Release Year          1
# Maturity Rating       0
# Original Audio     2636
# Recommendations      11
# dtype: int64
